# %%
import importlib
import pandas as pd
import numpy as np
import context # noqa
import brfinance.finance as bf
importlib.reload(bf)
pd.options.display.max_colwidth = 50
pd.options.display.max_rows = 40

# %%
bf.Finance.search_company('Petro')
# Out:
#                              company_name cvm_id           fiscal_id
# 0            3R PETROLEUM ÓLEO E GÁS S.A.  25291  12.091.809/0001-55
# 1                          PETRO RIO S.A.  22187  10.629.105/0001-68
# 2             PETROBRAS DISTRIBUIDORA S/A  24295  34.274.233/0001-02
# 3      PETROLEO BRASILEIRO S.A. PETROBRAS   9512  33.000.167/0001-01
# 4             PETROLEO LUB DO NORDESTE SA   9520  07.275.159/0001-68
# 5                     PETRORECÔNCAVO S.A.  25780  03.342.704/0001-30
# 6                  PRONOR PETROQUIMICA SA   9784  13.552.070/0001-02
# 7  REFINARIA DE PETROLEOS MANGUINHOS S.A.   9989  33.412.081/0001-96

# %%
# prio  22187 
# petro 9512
cia = bf.Finance(company_id='33.000.167/0001-01', account_basis='consolidated', unit=1_000_000, first_period='2016-01-01')
cia
# Out:
# Selected first_period = 2016-01-01
# Selected last_period = 2200-12-31

# %%
cia.operating_performance(is_on=True).tail(10)
# Out:
#                    2016-12-31  2017-12-31  2018-12-31  2019-12-31  2020-12-31  \
# return_on_assets          NaN    0.030971    0.049580    0.062666    0.035367
# return_on_capital         NaN    0.043979    0.074909    0.097621    0.053079
# return_on_equity          NaN    0.001492    0.099025    0.144493    0.020880
# gross_margin         0.318406    0.322864    0.382547    0.403993    0.455627
# operating_margin     0.038494    0.087877    0.132881    0.178407    0.120373
# net_margin          -0.046162    0.001329    0.086052    0.135552    0.022957
#
#                    2021-12-31
# return_on_assets     0.140921
# return_on_capital    0.217617
# return_on_equity     0.344734
# gross_margin         0.485205
# operating_margin     0.307396
# net_margin           0.236960

# %%
cia.info
# Out:
# {'CVM Number': 9512,
#  'Fiscal Number': '33.000.167/0001-01',
#  'Company Name': 'PETROLEO BRASILEIRO S.A. PETROBRAS',
#  'First Annual Report': '2010-12-31',
#  'Last Annual Report': '2021-12-31',
#  'Last Quarterly Report': '2021-09-30'}

# %%
cia.assets
# Out:
#                         account_name   account_code  account_fixed  \
# 0                        Ativo Total              1           True
# 1                   Ativo Circulante           1.01           True
# 2      Caixa e Equivalentes de Caixa        1.01.01           True
# 3             Aplicações Financeiras        1.01.02           True
# 4                   Contas a Receber        1.01.03           True
# ..                               ...            ...            ...
# 38               Depósitos Judiciais  1.02.01.10.04          False
# 39  Outros Realizáveis a Longo Prazo  1.02.01.10.05          False
# 40                     Investimentos        1.02.02           True
# 41                       Imobilizado        1.02.03           True
# 42                        Intangível        1.02.04           True
#
#     2016-12-31  2017-12-31  2018-12-31  2019-12-31  2020-12-31  2021-12-31
# 0     804945.0    831515.0    860473.0    926011.0    987419.0    972951.0
# ...

# %%
cia.show_accounts = 2
cia.assets
# Out:
#                       account_name account_code  account_fixed  2016-12-31  \
# 0                      Ativo Total            1           True    804945.0
# 1                 Ativo Circulante         1.01           True    145907.0
# 2    Caixa e Equivalentes de Caixa      1.01.01           True     69108.0
# 3           Aplicações Financeiras      1.01.02           True      2556.0
# 4                 Contas a Receber      1.01.03           True     15543.0
# 5                         Estoques      1.01.04           True     27622.0
# 6             Tributos a Recuperar      1.01.06           True      8153.0
# 7        Outros Ativos Circulantes      1.01.08           True     22925.0
# 8             Ativo Não Circulante         1.02           True    659038.0
# 9   Ativo Realizável a Longo Prazo      1.02.01           True     66551.0
# 10                   Investimentos      1.02.02           True      9948.0
# ...

# %%
cia.equity.head(10)
# Out:
#                                     account_name account_code  account_fixed  \
# 0                 Patrimônio Líquido Consolidado         2.03           True
# 1                       Capital Social Realizado      2.03.01           True
# 2                            Reservas de Capital      2.03.02           True
# 3                             Reservas de Lucros      2.03.04           True
# 4                  Outros Resultados Abrangentes      2.03.08           True
# 5  Participação dos Acionistas Não Controladores      2.03.09           True
#
#    2016-12-31  2017-12-31  2018-12-31  2019-12-31  2020-12-31  2021-12-31
# 0    252743.0    269609.0    283543.0    299137.0    311150.0    389581.0
# 1    205432.0    205432.0    205432.0    205432.0    205432.0    205432.0
# 2      1035.0      2457.0      2458.0      2449.0      2449.0      3097.0
# 3     77800.0     77364.0     95364.0    124829.0    127512.0    164244.0
# ...

# %%
cia.liabilities_and_equity.head(10)
# Out:
#                                         account_name account_code  \
# 0                                      Passivo Total            2
# 1                                 Passivo Circulante         2.01
# 2                  Obrigações Sociais e Trabalhistas      2.01.01
# 3                                       Fornecedores      2.01.02
# 4                                 Obrigações Fiscais      2.01.03
# 5                       Empréstimos e Financiamentos      2.01.04
# 6                                  Outras Obrigações      2.01.05
# 7                                          Provisões      2.01.06
# 8  Passivos sobre Ativos Não-Correntes a Venda e ...      2.01.07
# 9                             Passivo Não Circulante         2.02
#
#    account_fixed  2016-12-31  2017-12-31  2018-12-31  2019-12-31  2020-12-31  \
# 0           True    804945.0    831515.0    860473.0    926011.0    987419.0
# 1           True     81167.0     82535.0     97068.0    116147.0    136287.0
# ...

# %%
cia.income
# Out:
#                                          account_name account_code  \
# 0              Receita de Venda de Bens e/ou Serviços         3.01
# 1               Custo dos Bens e/ou Serviços Vendidos         3.02
# 2                                     Resultado Bruto         3.03
# 3                      Despesas/Receitas Operacionais         3.04
# 4                                 Despesas com Vendas      3.04.01
# 5                   Despesas Gerais e Administrativas      3.04.02
# 6                        Outras Despesas Operacionais      3.04.05
# 7                                         Tributárias   3.04.05.01
# 8    Custo com Pesquisa e Desenvolvimento Tecnológico   3.04.05.02
# 9   Custo Exploratório para Extração de Petróleo e...   3.04.05.03
# 10     Outras Despesas/Receitas Operacionais Líquidas   3.04.05.05
# 11  Reversão/Perdas no valor de recuperação de ati...   3.04.05.07
# 12              Resultado de Equivalência Patrimonial      3.04.06
# ...

# %%
# cia.earnings_per_share

# %%
cia.show_accounts = 1
cia.income

# %%
df = cia.cash_flow
df
# Out:
#                                           account_name account_code  \
# 0                Caixa Líquido Atividades Operacionais         6.01
# 1                           Caixa Gerado nas Operações      6.01.01
# 2              Lucro (Prejuízo) Consolidado do Período   6.01.01.01
# 3                        Lucro (Prejuízo) do Exercício   6.01.01.01
# 4                           Lucro líquido do exercício   6.01.01.01
# ..                                                 ...          ...
# 101  Operações descontinuadas-Recursos líquidos ger...      6.03.09
# 102           Variação Cambial s/ Caixa e Equivalentes         6.04
# 103          Aumento (Redução) de Caixa e Equivalentes         6.05
# 104              Saldo Inicial de Caixa e Equivalentes      6.05.01
# 105                Saldo Final de Caixa e Equivalentes      6.05.02
#
#      account_fixed  2016-12-31  2017-12-31  2018-12-31  2019-12-31  \
# 0             True     89709.0     86467.0     95846.0    101766.0
# ...

# %%
# df.query('account_code.str.startswith("6.01")')
value = ''
if value:
    print('com texto')
else:
    print('sem texto')
# Out:
# sem texto
