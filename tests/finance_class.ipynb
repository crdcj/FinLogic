# %%
import importlib
import pandas as pd
import context # noqa
import brfinance.finance
from brfinance.finance import Finance
importlib.reload(brfinance.finance)
pd.options.display.max_colwidth = 50
pd.options.display.max_rows = 40

# %%
rrrp = Finance(25291, report_type='consolidated', unit=1_000_000)
rrrp
# Out:
# Selected min_end_period = 2009-12-31
# Selected max_end_period = 2200-12-31

# %%
rrrp.info
# Out:
# {'CVM number': 25291,
#  'Fiscal Code': '12.091.809/0001-55',
#  'Name': '3R PETROLEUM ÓLEO E GÁS S.A.',
#  'Annual Reports': ['2019-12-31', '2020-12-31', '2021-12-31'],
#  'Last Quarterly Report': '2021-09-30'}

# %%
rrrp.assets
# Out:
#                                              DS_CONTA       CD_CONTA  \
# 0                                         Ativo Total              1
# 1                                    Ativo Circulante           1.01
# 2                       Caixa e Equivalentes de Caixa        1.01.01
# 3                              Aplicações Financeiras        1.01.02
# 4   Aplicações Financeiras Avaliadas ao Custo Amor...     1.01.02.03
# 5                                    Contas a Receber        1.01.03
# 6                                            Clientes     1.01.03.01
# 7                                            Estoques        1.01.04
# 8                                Tributos a Recuperar        1.01.06
# 9                      Tributos Correntes a Recuperar     1.01.06.01
# 10                               Despesas Antecipadas        1.01.07
# 11                          Outros Ativos Circulantes        1.01.08
# 12                                             Outros     1.01.08.03
# ...

# %%
rrrp.show_accounts = 2
rrrp.assets
# Out:
#                           DS_CONTA CD_CONTA  ST_CONTA_FIXA  2018-12-31  \
# 0                      Ativo Total        1           True     425.782
# 1                 Ativo Circulante     1.01           True     103.470
# 2    Caixa e Equivalentes de Caixa  1.01.01           True      82.757
# 3           Aplicações Financeiras  1.01.02           True         NaN
# 4                 Contas a Receber  1.01.03           True       7.024
# 5                         Estoques  1.01.04           True         NaN
# 6             Tributos a Recuperar  1.01.06           True       8.202
# 7             Despesas Antecipadas  1.01.07           True       1.858
# 8        Outros Ativos Circulantes  1.01.08           True       3.629
# 9             Ativo Não Circulante     1.02           True     322.312
# 10  Ativo Realizável a Longo Prazo  1.02.01           True      47.304
# 11                   Investimentos  1.02.02           True         NaN
# ...

# %%
rrrp.earnings_per_share

# %%
df = rrrp.income
df
# Out:
#                                              DS_CONTA CD_CONTA  ST_CONTA_FIXA  \
# 0              Receita de Venda de Bens e/ou Serviços     3.01           True
# 1               Custo dos Bens e/ou Serviços Vendidos     3.02           True
# 2                                     Resultado Bruto     3.03           True
# 3                      Despesas/Receitas Operacionais     3.04           True
# 4                   Despesas Gerais e Administrativas  3.04.02           True
# 5                        Outras Receitas Operacionais  3.04.04           True
# 6                        Outras Despesas Operacionais  3.04.05           True
# 7   Resultado Antes do Resultado Financeiro e dos ...     3.05           True
# 8                                Resultado Financeiro     3.06           True
# 9                                Receitas Financeiras  3.06.01           True
# 10                               Despesas Financeiras  3.06.02           True
# ...

# %%
rrrp.cash_flow
# Out:
#                                       DS_CONTA    CD_CONTA  ST_CONTA_FIXA  \
# 0        Caixa Líquido Atividades Operacionais        6.01           True
# 1                   Caixa Gerado nas Operações     6.01.01           True
# 2                        Prejuízo do exercício  6.01.01.01          False
# 3   Depreciação de bens, planta e equipamento.  6.01.01.02          False
# 4                    Amortização do intangível  6.01.01.03          False
# ..                                         ...         ...            ...
# 60          Amortização principal - Debêntures     6.03.07          False
# 61    Variação Cambial s/ Caixa e Equivalentes        6.04           True
# 62   Aumento (Redução) de Caixa e Equivalentes        6.05           True
# 63       Saldo Inicial de Caixa e Equivalentes     6.05.01           True
# 64         Saldo Final de Caixa e Equivalentes     6.05.02           True
#
#     2018-12-31  2019-12-31  2020-12-31  2021-12-31
# ...

# %%
df = rrrp.valuation
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/crcj/GitHub/BrFin/tests/finance_class.ipynb Cell 8' in <module>
# ----> <a href='vscode-notebook-cell:/home/crcj/GitHub/BrFin/tests/finance_class.ipynb#ch0000007?line=0'>1</a> df = rrrp.valuation
#       <a href='vscode-notebook-cell:/home/crcj/GitHub/BrFin/tests/finance_class.ipynb#ch0000007?line=1'>2</a> df
#
# File ~/GitHub/BrFin/brfinance/finance.py:283, in Finance.valuation(self)
#     <a href='file:///home/crcj/GitHub/BrFin/brfinance/finance.py?line=280'>281</a> df_as = self.assets
#     <a href='file:///home/crcj/GitHub/BrFin/brfinance/finance.py?line=281'>282</a> df_le = self.liabilities_and_equity
# --> <a href='file:///home/crcj/GitHub/BrFin/brfinance/finance.py?line=282'>283</a> df_is = self.income_statement
# ...

# %%
accounts = [  # noqa
    '3.01', '3.02', '3.03', '3.04', '3.04.01', '3.04.02', '3.04.03',
    '3.04.04', '3.04.05', '3.04.06', '3.05', '3.06', '3.07', '3.08',
    '3.09', '3.10', '3.10.01', '3.11', '1.01', '1.01.01', '1.01.02',
    '1.01.03', '1.01.04', '1.01.05', '1.01.06', '1.01.07', '1.01.08',
    '1.02.01', '1.02.02', '1.02.03', '1.02.04', '2.01', '2.01.01',
    '2.01.02', '2.01.03', '2.01.04', '2.01.05', '2.01.06', '2.02',
    '2.02.01', '2.02.02', '2.02.03', '2.02.04', '2.03', '2.03.09',
]

cat_size_order = pd.CategoricalDtype(accounts, ordered=True)
df['CD_CONTA'] = df['CD_CONTA'].astype(cat_size_order)
df.sort_values('CD_CONTA', inplace=True, ignore_index=True)
df.to_excel('rrrp.xlsx')

# %%
rrrp.assets
# Out:
#                                              DS_CONTA       CD_CONTA  \
# 0                                         Ativo Total              1
# 1                                    Ativo Circulante           1.01
# 2                       Caixa e Equivalentes de Caixa        1.01.01
# 3                              Aplicações Financeiras        1.01.02
# 4   Aplicações Financeiras Avaliadas ao Custo Amor...     1.01.02.03
# 5                                    Contas a Receber        1.01.03
# 6                                            Clientes     1.01.03.01
# 7                                            Estoques        1.01.04
# 8                                Tributos a Recuperar        1.01.06
# 9                      Tributos Correntes a Recuperar     1.01.06.01
# 10                               Despesas Antecipadas        1.01.07
# 11                          Outros Ativos Circulantes        1.01.08
# 12                                             Outros     1.01.08.03
# ...

# %%
petro = Finance(9512, min_end_period='2015-12-31', unit=1_000_000_000)
df = petro.assets
df
# Out:
# Selected min_end_period = 2015-12-31
# Selected max_end_period = 2200-12-31
#                             DS_CONTA       CD_CONTA  ST_CONTA_FIXA  \
# 0                        Ativo Total              1           True
# 1                   Ativo Circulante           1.01           True
# 2      Caixa e Equivalentes de Caixa        1.01.01           True
# 3             Aplicações Financeiras        1.01.02           True
# 4                   Contas a Receber        1.01.03           True
# ..                               ...            ...            ...
# 39               Depósitos Judiciais  1.02.01.10.04          False
# 40  Outros Realizáveis a Longo Prazo  1.02.01.10.05          False
# 41                     Investimentos        1.02.02           True
# 42                       Imobilizado        1.02.03           True
# 43                        Intangível        1.02.04           True
#
#     2015-12-31  2016-12-31  2017-12-31  2018-12-31  2019-12-31  2020-12-31  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DS_CONTA       43 non-null     object
#  1   CD_CONTA       43 non-null     object
#  2   ST_CONTA_FIXA  43 non-null     bool
#  3   2015-12-31     30 non-null     float64
#  4   2016-12-31     29 non-null     float64
#  5   2017-12-31     38 non-null     float64
#  6   2018-12-31     29 non-null     float64
#  7   2019-12-31     28 non-null     float64
#  8   2020-12-31     27 non-null     float64
#  9   2021-09-30     27 non-null     float64
# dtypes: bool(1), float64(7), object(2)
# memory usage: 3.2+ KB

# %%
df = petro.liabilities_and_equity
df
# Out:
#                DS_CONTA CD_CONTA  ST_CONTA_FIXA    2015-12-31    2016-12-31  \
# 0         Passivo Total        2           True  9.001350e+11  8.049450e+11
# 1    Passivo Circulante     2.01           True  1.115720e+11  8.116700e+10
# 2   Obrigações Socia...  2.01.01           True  5.085000e+09  7.159000e+09
# 3          Fornecedores  2.01.02           True  2.488800e+10  1.878100e+10
# 4    Obrigações Fiscais  2.01.03           True  4.100000e+08  4.120000e+08
# ..                  ...      ...            ...           ...           ...
# 43  Capital Social R...  2.03.01           True  2.054320e+11  2.054320e+11
# 44  Reservas de Capital  2.03.02           True  2.100000e+07  1.035000e+09
# 45   Reservas de Lucros  2.03.04           True  9.261200e+10  7.780000e+10
# 46  Outros Resultado...  2.03.08           True -4.333400e+10 -3.403700e+10
# 47  Participação dos...  2.03.09           True  3.199000e+09  2.513000e+09
#
# ...

# %%
df.sort_values('DS_CONTA').tail(10)
# Out:
#                DS_CONTA       CD_CONTA  ST_CONTA_FIXA    2015-12-31  \
# 38  Plano de Pensão ...  2.02.04.02.04          False  4.761800e+10
# 39  Provisão para De...  2.02.04.02.05          False  3.572800e+10
# 35            Provisões        2.02.04           True  9.411100e+10
# 18            Provisões        2.01.06           True  2.556000e+09
# 20     Provisões Cíveis  2.01.06.01.04           True           NaN
# 36  Provisões Fiscai...     2.02.04.01           True  8.776000e+09
# 19  Provisões Fiscai...     2.01.06.01           True           NaN
# 44  Reservas de Capital        2.03.02           True  2.100000e+07
# 45   Reservas de Lucros        2.03.04           True  9.261200e+10
# 33   Tributos Diferidos        2.02.03           True  9.060000e+08
#
#       2016-12-31    2017-12-31    2018-12-31    2019-12-31    2020-12-31  \
# 38  6.999600e+10  6.942100e+10  8.501200e+10  1.032130e+11  7.545400e+10
# ...

# %%
petro.equity
# Out:
#               DS_CONTA CD_CONTA  ST_CONTA_FIXA    2015-12-31    2016-12-31  \
# 0  Patrimônio Líqui...     2.03           True  2.579300e+11  2.527430e+11
# 1  Capital Social R...  2.03.01           True  2.054320e+11  2.054320e+11
# 2  Reservas de Capital  2.03.02           True  2.100000e+07  1.035000e+09
# 3   Reservas de Lucros  2.03.04           True  9.261200e+10  7.780000e+10
# 4  Outros Resultado...  2.03.08           True -4.333400e+10 -3.403700e+10
# 5  Participação dos...  2.03.09           True  3.199000e+09  2.513000e+09
#
#      2017-12-31    2018-12-31    2019-12-31    2020-12-31    2021-09-30
# 0  2.696090e+11  2.835430e+11  2.991370e+11  3.111500e+11  3.756890e+11
# 1  2.054320e+11  2.054320e+11  2.054320e+11  2.054320e+11  2.054320e+11
# 2  2.457000e+09  2.458000e+09  2.449000e+09  2.449000e+09 -1.254000e+09
# 3  7.736400e+10  9.536400e+10  1.248290e+11  1.275120e+11  1.651100e+11
# 4 -2.126800e+10 -2.602900e+10 -3.716900e+10 -2.698300e+10 -2.110000e+08
# ...

# %%
cols = petro._df_main.columns
df = petro._df_main[cols[3:-2]]
df
# Out:
#    report_period report_type   DT_REFER VERSAO DT_INI_EXERC DT_FIM_EXERC  \
# 0         annual    separate 2015-12-31      1   2015-01-01   2015-12-31
# 1         annual    separate 2016-12-31      2   2015-01-01   2015-12-31
# 2         annual    separate 2016-12-31      2   2016-01-01   2016-12-31
# 3         annual    separate 2017-12-31      2   2016-01-01   2016-12-31
# 4         annual    separate 2017-12-31      2   2017-01-01   2017-12-31
# 5         annual    separate 2018-12-31      1   2017-01-01   2017-12-31
# 6         annual    separate 2018-12-31      1   2018-01-01   2018-12-31
# 7         annual    separate 2019-12-31      1   2018-01-01   2018-12-31
# 8         annual    separate 2019-12-31      1   2019-01-01   2019-12-31
# 9      quarterly    separate 2020-03-31      1   2019-01-01   2019-03-31
# 10     quarterly    separate 2020-03-31      1   2020-01-01   2020-03-31
# 11     quarterly    separate 2020-06-30      1   2019-01-01   2019-06-30
# ...

# %%
last_afs = df.query('report_period == "annual"')['DT_FIM_EXERC'].max()
last_qfs = df.query('report_period == "quarterly"')['DT_FIM_EXERC'].max()
last_qfs > last_afs
# Out:
# True

# %%
df1 = df.query('DT_FIM_EXERC == @last_qfs').copy()
df1.reset_index(drop=True, inplace=True)
df1
# Out:
#   report_period report_type   DT_REFER VERSAO DT_INI_EXERC DT_FIM_EXERC  \
# 0     quarterly    separate 2021-09-30      1   2021-01-01   2021-09-30
# 1     quarterly    separate 2021-09-30      1   2021-07-01   2021-09-30
#
#    ORDEM_EXERC CD_CONTA             DS_CONTA  ST_CONTA_FIXA COLUNA_DF  \
# 0            0     3.01  Receita de Venda...           True       NaN
# 1            0     3.01  Receita de Venda...           True       NaN
#
#        VL_CONTA
# 0  3.126460e+11
# 1  1.177860e+11

# %%
df1.query('DT_INI_EXERC == DT_INI_EXERC.min()',
    inplace=True)
df1
# Out:
#   report_period report_type   DT_REFER VERSAO DT_INI_EXERC DT_FIM_EXERC  \
# 0     quarterly    separate 2021-09-30      1   2021-01-01   2021-09-30
#
#    ORDEM_EXERC CD_CONTA             DS_CONTA  ST_CONTA_FIXA COLUNA_DF  \
# 0            0     3.01  Receita de Venda...           True       NaN
#
#        VL_CONTA
# 0  3.126460e+11

# %%
df2 = df.query('DT_REFER == @last_qfs').copy()
df2
# Out:
#    report_period report_type   DT_REFER VERSAO DT_INI_EXERC DT_FIM_EXERC  \
# 27     quarterly    separate 2021-09-30      1   2020-01-01   2020-09-30
# 28     quarterly    separate 2021-09-30      1   2020-07-01   2020-09-30
# 29     quarterly    separate 2021-09-30      1   2021-01-01   2021-09-30
# 30     quarterly    separate 2021-09-30      1   2021-07-01   2021-09-30
#
#     ORDEM_EXERC CD_CONTA             DS_CONTA  ST_CONTA_FIXA COLUNA_DF  \
# 27           -1     3.01  Receita de Venda...           True       NaN
# 28           -1     3.01  Receita de Venda...           True       NaN
# 29            0     3.01  Receita de Venda...           True       NaN
# 30            0     3.01  Receita de Venda...           True       NaN
#
#         VL_CONTA
# 27  1.832220e+11
# 28  6.618200e+10
# 29  3.126460e+11
# 30  1.177860e+11

# %%
df2.query('DT_INI_EXERC == DT_INI_EXERC.min()', inplace=True)
df2['VL_CONTA'] = -df2['VL_CONTA']
df2.reset_index(drop=True, inplace=True)
df2
# Out:
#   report_period report_type   DT_REFER VERSAO DT_INI_EXERC DT_FIM_EXERC  \
# 0     quarterly    separate 2021-09-30      1   2020-01-01   2020-09-30
#
#    ORDEM_EXERC CD_CONTA             DS_CONTA  ST_CONTA_FIXA COLUNA_DF  \
# 0           -1     3.01  Receita de Venda...           True       NaN
#
#        VL_CONTA
# 0 -1.832220e+11

# %%
df3 = df.query('DT_FIM_EXERC == @last_afs').copy()
df3.reset_index(drop=True, inplace=True)
df3
# Out:
#   report_period report_type   DT_REFER VERSAO DT_INI_EXERC DT_FIM_EXERC  \
# 0        annual    separate 2020-12-31      2   2020-01-01   2020-12-31
#
#    ORDEM_EXERC CD_CONTA             DS_CONTA  ST_CONTA_FIXA COLUNA_DF  \
# 0            0     3.01  Receita de Venda...           True       NaN
#
#        VL_CONTA
# 0  2.539930e+11

# %%
df_ltm = pd.concat([df1,df2,df3])
df_ltm
# Out:
#   report_period report_type   DT_REFER VERSAO DT_INI_EXERC DT_FIM_EXERC  \
# 0     quarterly    separate 2021-09-30      1   2021-01-01   2021-09-30
# 0     quarterly    separate 2021-09-30      1   2020-01-01   2020-09-30
# 0        annual    separate 2020-12-31      2   2020-01-01   2020-12-31
#
#    ORDEM_EXERC CD_CONTA             DS_CONTA  ST_CONTA_FIXA COLUNA_DF  \
# 0            0     3.01  Receita de Venda...           True       NaN
# 0           -1     3.01  Receita de Venda...           True       NaN
# 0            0     3.01  Receita de Venda...           True       NaN
#
#        VL_CONTA
# 0  3.126460e+11
# 0 -1.832220e+11
# 0  2.539930e+11

# %%
df_ltm = df_ltm[['CD_CONTA', 'VL_CONTA']]
df_ltm
# Out:
#   CD_CONTA      VL_CONTA
# 0     3.01  3.126460e+11
# 0     3.01 -1.832220e+11
# 0     3.01  2.539930e+11

# %%
df_ltm = df_ltm.groupby(by='CD_CONTA').sum().reset_index()
df_ltm
# Out:
#   CD_CONTA      VL_CONTA
# 0     3.01  3.834170e+11

# %%
df1
# Out:
#   report_period report_type   DT_REFER VERSAO DT_INI_EXERC DT_FIM_EXERC  \
# 0     quarterly    separate 2021-09-30      1   2021-01-01   2021-09-30
#
#    ORDEM_EXERC CD_CONTA             DS_CONTA  ST_CONTA_FIXA COLUNA_DF  \
# 0            0     3.01  Receita de Venda...           True       NaN
#
#        VL_CONTA
# 0  3.126460e+11

# %%
df1.drop(columns='VL_CONTA', inplace=True)
df1
# Out:
#   report_period report_type   DT_REFER VERSAO DT_INI_EXERC DT_FIM_EXERC  \
# 0     quarterly    separate 2021-09-30      1   2021-01-01   2021-09-30
#
#    ORDEM_EXERC CD_CONTA             DS_CONTA  ST_CONTA_FIXA COLUNA_DF
# 0            0     3.01  Receita de Venda...           True       NaN

# %%
df_ltm = pd.merge(df1, df_ltm)
df_ltm
# Out:
#   report_period report_type   DT_REFER VERSAO DT_INI_EXERC DT_FIM_EXERC  \
# 0     quarterly    separate 2021-09-30      1   2021-01-01   2021-09-30
#
#    ORDEM_EXERC CD_CONTA             DS_CONTA  ST_CONTA_FIXA COLUNA_DF  \
# 0            0     3.01  Receita de Venda...           True       NaN
#
#        VL_CONTA
# 0  3.834170e+11

# %%
df_ltm['report_period'] = 'ltm'
df_ltm['DT_INI_EXERC'] = last_qfs - pd.DateOffset(years=1)
df_ltm
# Out:
#   report_period report_type   DT_REFER VERSAO DT_INI_EXERC DT_FIM_EXERC  \
# 0           ltm    separate 2021-09-30      1   2020-09-30   2021-09-30
#
#    ORDEM_EXERC CD_CONTA             DS_CONTA  ST_CONTA_FIXA COLUNA_DF  \
# 0            0     3.01  Receita de Venda...           True       NaN
#
#        VL_CONTA
# 0  3.834170e+11

# %%
teste = 1
if teste:
    print(teste)
# Out:
# 1
