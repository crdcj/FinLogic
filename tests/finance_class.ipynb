# %%
import importlib
import pandas as pd
import context # noqa
import brfinance.finance
from brfinance.finance import Finance
importlib.reload(brfinance.finance)
pd.options.display.max_colwidth = 50
pd.options.display.max_rows = 40

# %%
prio = Finance(22187, report_type='consolidated', unit=1_000_000, first_period='2016-01-01')
prio
# Out:
# Selected first_period = 2016-01-01
# Selected last_period = 2200-12-31

# %%
prio.info
# Out:
# {'CVM number': 22187,
#  'Fiscal Code': '10.629.105/0001-68',
#  'Name': 'PETRO RIO S.A.',
#  'Annual Reports': ['2010-12-31',
#   '2014-12-31',
#   '2021-12-31',
#   '2011-12-31',
#   '2019-12-31',
#   '2015-12-31',
#   '2018-12-31',
#   '2020-12-31',
#   '2013-12-31',
#   '2012-12-31',
#   '2016-12-31',
#   '2017-12-31'],
#  'Last Quarterly Report': '2021-09-30'}

# %%
prio.assets
# Out:
#                                           DS_CONTA       CD_CONTA  \
# 0                                      Ativo Total              1
# 1                                 Ativo Circulante           1.01
# 2                    Caixa e Equivalentes de Caixa        1.01.01
# 3                           Aplicações Financeiras        1.01.02
# 4   Aplicações Financeiras Avaliadas a Valor Justo     1.01.02.01
# ..                                             ...            ...
# 38                  Direito de Uso em Arrendamento     1.02.03.02
# 39                        Imobilizado em Andamento     1.02.03.03
# 40                                      Intangível        1.02.04
# 41                                     Intangíveis     1.02.04.01
# 42                           Contrato de Concessão  1.02.04.01.01
#
#     ST_CONTA_FIXA  2016-12-31  2017-12-31  2018-12-31  2019-12-31  2020-12-31  \
# 0            True    1082.369    1270.244    1516.180    5489.751    6792.833
# ...

# %%
prio.show_accounts = 2
prio.assets
# Out:
#                           DS_CONTA CD_CONTA  ST_CONTA_FIXA  2016-12-31  \
# 0                      Ativo Total        1           True    1082.369
# 1                 Ativo Circulante     1.01           True     781.580
# 2    Caixa e Equivalentes de Caixa  1.01.01           True      24.793
# 3           Aplicações Financeiras  1.01.02           True     546.507
# 4                 Contas a Receber  1.01.03           True      30.680
# 5                         Estoques  1.01.04           True      33.192
# 6             Tributos a Recuperar  1.01.06           True      69.331
# 7             Despesas Antecipadas  1.01.07           True       2.696
# 8        Outros Ativos Circulantes  1.01.08           True      74.381
# 9             Ativo Não Circulante     1.02           True     300.789
# 10  Ativo Realizável a Longo Prazo  1.02.01           True      73.972
# 11                     Imobilizado  1.02.03           True      44.234
# ...

# %%
prio.liabilities_and_equity
# Out:
#                                              DS_CONTA CD_CONTA  ST_CONTA_FIXA  \
# 0                                       Passivo Total        2           True
# 1                                  Passivo Circulante     2.01           True
# 2                   Obrigações Sociais e Trabalhistas  2.01.01           True
# 3                                        Fornecedores  2.01.02           True
# 4                                  Obrigações Fiscais  2.01.03           True
# 5                        Empréstimos e Financiamentos  2.01.04           True
# 6                                   Outras Obrigações  2.01.05           True
# 7   Passivos sobre Ativos Não-Correntes a Venda e ...  2.01.07           True
# 8                              Passivo Não Circulante     2.02           True
# 9                        Empréstimos e Financiamentos  2.02.01           True
# 10                                  Outras Obrigações  2.02.02           True
# ...

# %%
prio.operating_performance
# Out:
#                    2016-12-31   2017-12-31   2018-12-31   2019-12-31  \
# CD_CONTA
# 1                 1082.369000  1270.244000  1516.180000  5489.751000
# 2.03               834.152000   883.130000   982.174000  2165.101000
# 3.11               241.622000    50.851000   206.296000   842.346000
# return_on_assets     0.223234     0.040032     0.136063     0.153440
# return_on_equity     0.289662     0.057580     0.210040     0.389056
#
#                    2020-12-31    2021-12-31
# CD_CONTA
# 1                 6792.833000  12221.416000
# 2.03              3151.263000   6620.249000
# 3.11               452.913000   1333.046000
# return_on_assets     0.066675      0.109075
# return_on_equity     0.143724      0.201359

# %%
prio.earnings_per_share
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/crcj/GitHub/BrFin/tests/finance_class.ipynb Cell 8' in <module>
# ----> <a href='vscode-notebook-cell:/home/crcj/GitHub/BrFin/tests/finance_class.ipynb#ch0000005?line=0'>1</a> prio.earnings_per_share
#
# File ~/GitHub/BrFin/brfinance/finance.py:247, in Finance.earnings_per_share(self)
#     <a href='file:///home/crcj/GitHub/BrFin/brfinance/finance.py?line=244'>245</a> df = self._get_company_df()
#     <a href='file:///home/crcj/GitHub/BrFin/brfinance/finance.py?line=245'>246</a> df.query('account_level_1and2 == "3.99"', inplace=True)
# --> <a href='file:///home/crcj/GitHub/BrFin/brfinance/finance.py?line=246'>247</a> return self._make_report(df)
#
# File ~/GitHub/BrFin/brfinance/finance.py:346, in Finance._make_report(self, df)
# ...

# %%
prio.show_accounts = 1
prio.income
# Out:
#                                             DS_CONTA CD_CONTA  ST_CONTA_FIXA  \
# 0             Receita de Venda de Bens e/ou Serviços     3.01           True
# 1              Custo dos Bens e/ou Serviços Vendidos     3.02           True
# 2                                    Resultado Bruto     3.03           True
# 3                     Despesas/Receitas Operacionais     3.04           True
# 4  Resultado Antes do Resultado Financeiro e dos ...     3.05           True
# 5                               Resultado Financeiro     3.06           True
# 6         Resultado Antes dos Tributos sobre o Lucro     3.07           True
# 7  Imposto de Renda e Contribuição Social sobre o...     3.08           True
# 8        Resultado Líquido das Operações Continuadas     3.09           True
# 9              Lucro/Prejuízo Consolidado do Período     3.11           True
#
#    2016-12-31  2017-12-31  2018-12-31  2019-12-31  2020-12-31  2021-12-31
# ...

# %%
prio.cash_flow
# Out:
#                                     DS_CONTA CD_CONTA  ST_CONTA_FIXA  \
# 0      Caixa Líquido Atividades Operacionais     6.01           True
# 1   Caixa Líquido Atividades de Investimento     6.02           True
# 2  Caixa Líquido Atividades de Financiamento     6.03           True
# 3   Variação Cambial s/ Caixa e Equivalentes     6.04           True
# 4  Aumento (Redução) de Caixa e Equivalentes     6.05           True
#
#    2016-12-31  2017-12-31  2018-12-31  2019-12-31  2020-12-31  2021-12-31
# 0     114.000      49.087     246.428     444.671    1617.546    2183.736
# 1    -391.101       2.624    -281.433   -1383.308    -585.142   -4743.320
# 2      -5.699      13.861     121.033    1192.303    -713.295    2627.429
# 3      23.642       2.080       8.520      18.738      30.767      93.563
# 4    -259.158      67.652      94.548     272.404     349.876     161.408

# %%
prio.valuation
# Out:
#                                              DS_CONTA CD_CONTA  ST_CONTA_FIXA  \
# 1                                    Ativo Circulante     1.01           True
# 4                                  Passivo Circulante     2.01           True
# 5                              Passivo Não Circulante     2.02           True
# 6                      Patrimônio Líquido Consolidado     2.03           True
# 7              Receita de Venda de Bens e/ou Serviços     3.01           True
# 8               Custo dos Bens e/ou Serviços Vendidos     3.02           True
# 9                                     Resultado Bruto     3.03           True
# 10                     Despesas/Receitas Operacionais     3.04           True
# 11  Resultado Antes do Resultado Financeiro e dos ...     3.05           True
# 12                               Resultado Financeiro     3.06           True
# 13         Resultado Antes dos Tributos sobre o Lucro     3.07           True
# ...
