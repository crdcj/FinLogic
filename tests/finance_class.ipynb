# %%
import importlib
import pandas as pd
import context # noqa
import brfinance.finance as bf
importlib.reload(bf)
pd.options.display.max_colwidth = 50
pd.options.display.max_rows = 40

# %%
# prio  22187 
# petro 9512
cia = bf.Finance(9512, report_type='consolidated', unit=1_000_000, first_period='2016-01-01')
cia
# Out:
# Selected first_period = 2016-01-01
# Selected last_period = 2200-12-31

# %%
cia.info
# Out:
# {'CVM number': 9512,
#  'Fiscal Code': '33.000.167/0001-01',
#  'Name': 'PETROLEO BRASILEIRO S.A. PETROBRAS',
#  'Annual Reports': ['2010-12-31',
#   '2011-12-31',
#   '2012-12-31',
#   '2013-12-31',
#   '2014-12-31',
#   '2015-12-31',
#   '2016-12-31',
#   '2017-12-31',
#   '2018-12-31',
#   '2019-12-31',
#   '2020-12-31',
#   '2021-12-31'],
#  'Last Quarterly Report': '2021-09-30'}

# %%
cia.assets

# %%
cia.show_accounts = 2
cia.assets

# %%
cia.liabilities_and_equity

# %%
cia.income
# Out:
#                                              DS_CONTA    CD_CONTA  \
# 0              Receita de Venda de Bens e/ou Serviços        3.01
# 1               Custo dos Bens e/ou Serviços Vendidos        3.02
# 2                                     Resultado Bruto        3.03
# 3                      Despesas/Receitas Operacionais        3.04
# 4                                 Despesas com Vendas     3.04.01
# 5                   Despesas Gerais e Administrativas     3.04.02
# 6                        Outras Despesas Operacionais     3.04.05
# 7                                         Tributárias  3.04.05.01
# 8    Custo com Pesquisa e Desenvolvimento Tecnológico  3.04.05.02
# 9   Custo Exploratório para Extração de Petróleo e...  3.04.05.03
# 10     Outras Despesas/Receitas Operacionais Líquidas  3.04.05.05
# 11  Reversão/Perdas no valor de recuperação de ati...  3.04.05.07
# 12              Resultado de Equivalência Patrimonial     3.04.06
# ...

# %%
cia.operating_performance
# Out:
#                      2016-12-31     2017-12-31     2018-12-31     2019-12-31  \
# CD_CONTA
# 1                 804945.000000  831515.000000  860473.000000  926011.000000
# 2.03              252743.000000  269609.000000  283543.000000  299137.000000
# 3.01              282589.000000  283695.000000  310255.000000  302245.000000
# 3.02             -192611.000000 -192100.000000 -191568.000000 -180140.000000
# 3.03               89978.000000   91595.000000  118687.000000  122105.000000
# ...                         ...            ...            ...            ...
# return_on_equity      -0.051614       0.001398       0.094159       0.136961
# gross_margin           0.318406       0.322864       0.382547       0.403993
# ebit_margin            0.058325       0.133147       0.201334       0.270314
# operating_margin       0.228852       0.238887       0.311366       0.317593
# net_margin            -0.046162       0.001329       0.086052       0.135552
#
# ...

# %%
cia.earnings_per_share

# %%
cia.show_accounts = 1
cia.income

# %%
cia.cash_flow

# %%
cia.valuation

# %%
lista = [3,10,1]
lista.sort()
lista
