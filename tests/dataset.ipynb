# %%
import importlib
import pandas as pd
import context # noqa
pd.options.display.max_colwidth = 15
pd.options.display.max_rows = 40

# %%
# %%time
file_path = '/home/crcj/GitHub/BrFin/brfin/data/processed/dataset.pkl.zst'
DATASET = pd.read_pickle(file_path)
DATASET
# Out:
# CPU times: user 75.6 ms, sys: 39.6 ms, total: 115 ms
# Wall time: 115 ms
#          CD_CVM        CNPJ_CIA       DENOM_CIA report_period   report_type  \
# 0            94  92.693.019/...  PANATLANTIC...        annual  consolidated
# 1            94  92.693.019/...  PANATLANTIC...        annual  consolidated
# 2            94  92.693.019/...  PANATLANTIC...        annual  consolidated
# 3            94  92.693.019/...  PANATLANTIC...        annual  consolidated
# 4            94  92.693.019/...  PANATLANTIC...        annual  consolidated
# ...         ...             ...             ...           ...           ...
# 6828296  518700  70.216.429/...  BRAMEX - BR...        annual      separate
# 6828297  518700  70.216.429/...  BRAMEX - BR...        annual      separate
# 6828298  518700  70.216.429/...  BRAMEX - BR...        annual      separate
# 6828299  518700  70.216.429/...  BRAMEX - BR...        annual      separate
# 6828300  518700  70.216.429/...  BRAMEX - BR...        annual      separate
#
#           DT_REFER VERSAO DT_INI_EXERC DT_FIM_EXERC ORDEM_EXERC    CD_CONTA  \
# 0       2010-12-31      2          NaT   2009-12-31          -1           1
# 1       2010-12-31      2          NaT   2009-12-31          -1        1.01
# 2       2010-12-31      2          NaT   2009-12-31          -1     1.01.01
# 3       2010-12-31      2          NaT   2009-12-31          -1     1.01.02
# 4       2010-12-31      2          NaT   2009-12-31          -1  1.01.02.02
# ...            ...    ...          ...          ...         ...         ...
# 6828296 2013-12-31      1   2013-01-01   2013-12-31           0     7.08.03
# 6828297 2013-12-31      1   2013-01-01   2013-12-31           0  7.08.03.01
# 6828298 2013-12-31      1   2013-01-01   2013-12-31           0     7.08.04
# 6828299 2013-12-31      1   2013-01-01   2013-12-31           0  7.08.04.03
# 6828300 2013-12-31      1   2013-01-01   2013-12-31           0     7.08.05
#
#                DS_CONTA ST_CONTA_FIXA COLUNA_DF     VL_CONTA
# 0           Ativo Total          True       NaN  211293000.0
# 1        Ativo Circu...          True       NaN  164307000.0
# 2        Caixa e Equ...          True       NaN    2055000.0
# 3        Aplicações ...          True       NaN   44510000.0
# 4        Aplicações ...          True       NaN   44510000.0
# ...                 ...           ...       ...          ...
# 6828296  Remuneração...          True       NaN     328371.0
# 6828297           Juros          True       NaN     328371.0
# 6828298  Remuneração...          True       NaN   -1200611.0
# 6828299  Lucros Reti...          True       NaN   -1200611.0
# 6828300          Outros          True       NaN     486752.0
#
# [6828301 rows x 15 columns]

# %%
DATASET.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6828301 entries, 0 to 6828300
# Data columns (total 15 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   CD_CVM         category
#  1   CNPJ_CIA       category
#  2   DENOM_CIA      category
#  3   report_period  category
#  4   report_type    category
#  5   DT_REFER       category
#  6   VERSAO         category
#  7   DT_INI_EXERC   category
#  8   DT_FIM_EXERC   category
#  9   ORDEM_EXERC    category
#  10  CD_CONTA       category
#  11  DS_CONTA       category
#  12  ST_CONTA_FIXA  category
#  13  COLUNA_DF      category
#  14  VL_CONTA       category
# dtypes: category(15)
# memory usage: 212.0 MB

# %%
# df_dataset.query("CD_CVM == 9512")
# df_dataset.query("VL_CONTA == 0")
DATASET.VL_CONTA.nunique()
# Out:
# 992969

# %%
DATASET.query("COLUNA_DF.notnull()")
# Out:
#          CD_CVM        CNPJ_CIA       DENOM_CIA report_period   report_type  \
# 92           94  92.693.019/...  PANATLANTIC...        annual  consolidated
# 93           94  92.693.019/...  PANATLANTIC...        annual  consolidated
# 94           94  92.693.019/...  PANATLANTIC...        annual  consolidated
# 95           94  92.693.019/...  PANATLANTIC...        annual  consolidated
# 96           94  92.693.019/...  PANATLANTIC...        annual  consolidated
# ...         ...             ...             ...           ...           ...
# 6828262  518700  70.216.429/...  BRAMEX - BR...        annual      separate
# 6828263  518700  70.216.429/...  BRAMEX - BR...        annual      separate
# 6828264  518700  70.216.429/...  BRAMEX - BR...        annual      separate
# 6828265  518700  70.216.429/...  BRAMEX - BR...        annual      separate
# 6828266  518700  70.216.429/...  BRAMEX - BR...        annual      separate
#
#           DT_REFER VERSAO DT_INI_EXERC DT_FIM_EXERC ORDEM_EXERC CD_CONTA  \
# 92      2010-12-31      2   2009-01-01   2009-12-31          -1     5.01
# 93      2010-12-31      2   2009-01-01   2009-12-31          -1     5.01
# 94      2010-12-31      2   2009-01-01   2009-12-31          -1     5.01
# 95      2010-12-31      2   2009-01-01   2009-12-31          -1     5.01
# 96      2010-12-31      2   2009-01-01   2009-12-31          -1     5.01
# ...            ...    ...          ...          ...         ...      ...
# 6828262 2013-12-31      1   2013-01-01   2013-12-31           0  5.05.01
# 6828263 2013-12-31      1   2013-01-01   2013-12-31           0     5.07
# 6828264 2013-12-31      1   2013-01-01   2013-12-31           0     5.07
# 6828265 2013-12-31      1   2013-01-01   2013-12-31           0     5.07
# 6828266 2013-12-31      1   2013-01-01   2013-12-31           0     5.07
#
#                DS_CONTA ST_CONTA_FIXA       COLUNA_DF     VL_CONTA
# 92       Saldos Inic...          True  Capital Soc...   66060000.0
# 93       Saldos Inic...          True  Reservas de...     264000.0
# 94       Saldos Inic...          True  Reservas de...   47493000.0
# 95       Saldos Inic...          True  Patrimônio ...  113817000.0
# 96       Saldos Inic...          True  Patrimônio ...  113817000.0
# ...                 ...           ...             ...          ...
# 6828262  Lucro Líqui...          True  Patrimônio ...   -1200611.0
# 6828263   Saldos Finais          True  Capital Soc...   47291001.0
# 6828264   Saldos Finais          True  Reservas de...    1455881.0
# 6828265   Saldos Finais          True  Lucros ou P...  -36379890.0
# 6828266   Saldos Finais          True  Patrimônio ...   12366992.0
#
# [1278461 rows x 15 columns]
