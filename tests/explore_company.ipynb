# %%
import importlib
import pandas as pd
import context # noqa
import brfin.company
from brfin.company import Company
importlib.reload(brfin.company)
pd.options.display.max_colwidth = 20
pd.options.display.max_rows = 40

# %%
petro = Company(9512, report_type='separate', min_end_period='2015-12-31', max_end_period='2022-12-31')
petro.assets
#petro._companies_list
# Out:
# Selected min_end_period = 2015-12-31
# Selected max_end_period = 2022-12-31
#       DS_CONTA CD_CONTA  ST_CONTA_FIXA    2015-12-31    2016-12-31  \
# 0  Ativo Total        1           True  6.986460e+11  6.820880e+11
#
#      2017-12-31    2018-12-31    2019-12-31    2020-12-31    2021-09-30
# 0  7.238550e+11  8.397170e+11  1.129118e+12  1.178600e+12  1.239448e+12

# %%
petro = Company(9512, min_end_period='2015-12-31')
df = petro.assets
df
# Out:
# Selected min_end_period = 2015-12-31
# Selected max_end_period = 2200-12-31
#       DS_CONTA CD_CONTA  ST_CONTA_FIXA    2015-12-31    2016-12-31  \
# 0  Ativo Total        1           True  9.001350e+11  8.049450e+11
#
#      2017-12-31    2018-12-31    2019-12-31    2020-12-31    2021-09-30
# 0  8.315150e+11  8.604730e+11  9.260110e+11  9.874190e+11  9.746890e+11

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DS_CONTA       1 non-null      object
#  1   CD_CONTA       1 non-null      object
#  2   ST_CONTA_FIXA  1 non-null      bool
#  3   2015-12-31     1 non-null      float64
#  4   2016-12-31     1 non-null      float64
#  5   2017-12-31     1 non-null      float64
#  6   2018-12-31     1 non-null      float64
#  7   2019-12-31     1 non-null      float64
#  8   2020-12-31     1 non-null      float64
#  9   2021-09-30     1 non-null      float64
# dtypes: bool(1), float64(7), object(2)
# memory usage: 201.0+ bytes

# %%
df = petro.liabilities_and_equity
df
# Out:
#                DS_CONTA CD_CONTA  ST_CONTA_FIXA    2015-12-31    2016-12-31  \
# 0         Passivo Total        2           True  9.001350e+11  8.049450e+11
# 1    Passivo Circulante     2.01           True  1.115720e+11  8.116700e+10
# 2   Obrigações Socia...  2.01.01           True  5.085000e+09  7.159000e+09
# 3          Fornecedores  2.01.02           True  2.488800e+10  1.878100e+10
# 4    Obrigações Fiscais  2.01.03           True  4.100000e+08  4.120000e+08
# ..                  ...      ...            ...           ...           ...
# 43  Capital Social R...  2.03.01           True  2.054320e+11  2.054320e+11
# 44  Reservas de Capital  2.03.02           True  2.100000e+07  1.035000e+09
# 45   Reservas de Lucros  2.03.04           True  9.261200e+10  7.780000e+10
# 46  Outros Resultado...  2.03.08           True -4.333400e+10 -3.403700e+10
# 47  Participação dos...  2.03.09           True  3.199000e+09  2.513000e+09
#
# ...

# %%
df.sort_values('DS_CONTA').tail(10)
# Out:
#       DS_CONTA CD_CONTA  ST_CONTA_FIXA    2015-12-31    2016-12-31  \
# 0  Ativo Total        1           True  9.001350e+11  8.049450e+11
#
#      2017-12-31    2018-12-31    2019-12-31    2020-12-31    2021-09-30
# 0  8.315150e+11  8.604730e+11  9.260110e+11  9.874190e+11  9.746890e+11

# %%
petro.equity
# Out:
#                DS_CONTA    CD_CONTA  ST_CONTA_FIXA    2009-12-31  \
# 0    Patrimônio Líquido        2.03           True  1.650207e+11
# 1   Capital Social R...     2.03.01           True  7.896669e+10
# 2   Reservas de Capital     2.03.02           True  1.937392e+09
# 3   Contribuição Adi...  2.03.02.07          False           NaN
# 4   Incentivos Fisca...  2.03.02.08          False  5.148570e+08
# 5   Mudança de Parti...  2.03.02.09          False  1.422535e+09
# 6   Gastos com Emiss...  2.03.02.10          False           NaN
# 7    Reservas de Lucros     2.03.04           True  8.543076e+10
# 8         Reserva Legal  2.03.04.01           True  1.090166e+10
# 9   Reserva Estatutária  2.03.04.02           True  1.294209e+09
# 10  Reserva de Reten...  2.03.04.05           True  7.212326e+10
# 11  Reserva de Incen...  2.03.04.07           True  1.111632e+09
# 12  Lucros/Prejuízos...     2.03.05           True -1.247335e+09
# ...

# %%
date = pd.to_datetime('2200-12-30', errors='coerce')
date.strftime('%Y-%m-%d')
print(date.date())
# Out:
# 2200-12-30

# %%
petro._df_main
# Out:
#    CD_CVM            CNPJ_CIA            DENOM_CIA report_frequency  \
# 0    9512  33.000.167/0001-01  PETROLEO BRASILE...           annual
# 1    9512  33.000.167/0001-01  PETROLEO BRASILE...           annual
# 2    9512  33.000.167/0001-01  PETROLEO BRASILE...           annual
# 3    9512  33.000.167/0001-01  PETROLEO BRASILE...           annual
# 4    9512  33.000.167/0001-01  PETROLEO BRASILE...           annual
# 5    9512  33.000.167/0001-01  PETROLEO BRASILE...           annual
# 6    9512  33.000.167/0001-01  PETROLEO BRASILE...           annual
# 7    9512  33.000.167/0001-01  PETROLEO BRASILE...           annual
# 8    9512  33.000.167/0001-01  PETROLEO BRASILE...           annual
# 9    9512  33.000.167/0001-01  PETROLEO BRASILE...        quarterly
# 10   9512  33.000.167/0001-01  PETROLEO BRASILE...        quarterly
# 11   9512  33.000.167/0001-01  PETROLEO BRASILE...        quarterly
# 12   9512  33.000.167/0001-01  PETROLEO BRASILE...        quarterly
# ...

# %%
df.reset_index(drop=True, inplace=True)
