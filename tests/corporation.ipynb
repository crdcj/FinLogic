# %%
import pandas as pd
import context # noqa
import brfinance as bf

pd.options.display.max_colwidth = 50
pd.options.display.max_rows = 40
print(bf.__version__)
print(bf.__author__)
# Out:
# 0.1.1
# Carlos Carvalho

# %%
bf.dataset_info()
# Out:
#                                       Dataset Info
# Number of account values (total rows)      7003913
# Number of unique account codes                1902
# Number of corporations                        1082
# Number of Financial Statements               11755
# First Financial Statement               2009-01-31
# Last Financial Statement                2022-03-31

# %%
bf.search_in_dataset('petro')
# Out:
#                                 corp_name corp_cvm_id      corp_fiscal_id
# 0            3R PETROLEUM ÓLEO E GÁS S.A.       25291  12.091.809/0001-55
# 1                          PETRO RIO S.A.       22187  10.629.105/0001-68
# 2             PETROBRAS DISTRIBUIDORA S/A       24295  34.274.233/0001-02
# 3      PETROLEO BRASILEIRO S.A. PETROBRAS        9512  33.000.167/0001-01
# 4             PETROLEO LUB DO NORDESTE SA        9520  07.275.159/0001-68
# 5                     PETRORECÔNCAVO S.A.       25780  03.342.704/0001-30
# 6                  PRONOR PETROQUIMICA SA        9784  13.552.070/0001-02
# 7  REFINARIA DE PETROLEOS MANGUINHOS S.A.        9989  33.412.081/0001-96

# %%
# prio  22187
# petro 9512
# brasilagro
corp = bf.Corporation(9512)
corp.info()
# Out:
#                                           Corporation Info
# Corp. Name              PETROLEO BRASILEIRO S.A. PETROBRAS
# Corp. CVM ID                                          9512
# Corp. Fiscal ID (CNPJ)                  33.000.167/0001-01
# First Annual Report                             2009-12-31
# Last Annual Report                              2021-12-31
# Last Quarterly Report                           2021-09-30

# %%
# corporation.corporation_id = 9512

# %%
corp.report(report_type='assets')
# Out:
#                      account_name   account_code  account_fixed    2009-12-31  \
# 0                     Ativo Total              1           True  3.504189e+11
# 1                Ativo Circulante           1.01           True  7.437357e+10
# 2   Caixa e Equivalentes de Caixa        1.01.01           True  2.903423e+10
# 3                  Caixa e Bancos     1.01.01.01          False  2.853964e+09
# 4          Aplicações Financeiras     1.01.01.02          False  2.618026e+10
# ..                            ...            ...            ...           ...
# 67                     Intangível        1.02.04           True  8.270864e+09
# 68                    Intangíveis     1.02.04.01           True  7.346025e+09
# 69          Direitos e Concessões  1.02.04.01.02          False  5.606748e+09
# 70                      Softwares  1.02.04.01.03          False  1.739277e+09
# 71                       Goodwill     1.02.04.02           True  9.248390e+08
#
#       2010-12-31    2011-12-31    2012-12-31    2013-12-31    2014-12-31  \
# 0   5.168457e+11  6.000970e+11  6.690316e+11  7.529670e+11  7.933750e+11
# 1   1.059022e+11  1.211637e+11  1.181018e+11  1.233510e+11  1.350230e+11
# 2   2.941619e+10  3.574724e+10  2.762800e+10  3.717200e+10  4.423900e+10
# 3   3.293879e+09  3.731249e+09  2.024301e+09           NaN           NaN
# 4   2.612231e+10  3.201599e+10  2.560370e+10           NaN           NaN
# ..           ...           ...           ...           ...           ...
# 67  8.153873e+10  8.143361e+10  8.120676e+10  3.612100e+10  1.197600e+10
# 68  8.063279e+10  8.048451e+10  8.026607e+10           NaN           NaN
# 69  7.895228e+10  7.880350e+10  7.870176e+10           NaN           NaN
# 70  1.680513e+09  1.681011e+09  1.564311e+09           NaN           NaN
# 71  9.059360e+08  9.491000e+08  9.406830e+08           NaN           NaN
#
#       2015-12-31    2016-12-31    2017-12-31    2018-12-31    2019-12-31  \
# 0   9.001350e+11  8.049450e+11  8.315150e+11  8.604730e+11  9.260110e+11
# 1   1.686070e+11  1.459070e+11  1.559090e+11  1.436060e+11  1.121010e+11
# 2   9.784500e+10  6.910800e+10  7.449400e+10  5.385400e+10  2.971400e+10
# 3            NaN           NaN           NaN           NaN           NaN
# 4            NaN           NaN           NaN           NaN           NaN
# ..           ...           ...           ...           ...           ...
# 67  1.207200e+10  1.066300e+10  7.740000e+09  1.087000e+10  7.848900e+10
# 68           NaN           NaN           NaN           NaN           NaN
# 69           NaN           NaN           NaN           NaN           NaN
# 70           NaN           NaN           NaN           NaN           NaN
# 71           NaN           NaN           NaN           NaN           NaN
#
#       2020-12-31    2021-12-31
# 0   9.874190e+11  9.729510e+11
# 1   1.423230e+11  1.682470e+11
# 2   6.085600e+10  5.841000e+10
# 3            NaN           NaN
# 4            NaN           NaN
# ..           ...           ...
# 67  7.767800e+10  1.687900e+10
# 68           NaN           NaN
# 69           NaN           NaN
# 70           NaN           NaN
# 71           NaN           NaN
#
# [72 rows x 16 columns]

# %%
corp.report(
    report_type='assets',
    accounting_method='separate',
    unit=1_000_000,
    account_level=3,
    first_period='2015-01-01'
)
# Out:
#                       account_name account_code  account_fixed  2015-12-31  \
# 0                      Ativo Total            1           True    698646.0
# 1                 Ativo Circulante         1.01           True     81479.0
# 2    Caixa e Equivalentes de Caixa      1.01.01           True     16553.0
# 3           Aplicações Financeiras      1.01.02           True      2982.0
# 4                 Contas a Receber      1.01.03           True     27701.0
# 5                         Estoques      1.01.04           True     24015.0
# 6             Tributos a Recuperar      1.01.06           True      6506.0
# 7        Outros Ativos Circulantes      1.01.08           True      3722.0
# 8             Ativo Não Circulante         1.02           True    617167.0
# 9   Ativo Realizável a Longo Prazo      1.02.01           True     50059.0
# 10                   Investimentos      1.02.02           True    115536.0
# 11                     Imobilizado      1.02.03           True    442439.0
# 12                      Intangível      1.02.04           True      9133.0
#
#     2016-12-31  2017-12-31  2018-12-31  2019-12-31  2020-12-31  2021-12-31
# 0     682088.0    723855.0    839717.0   1129118.0   1178600.0   1248196.0
# 1      81264.0     81883.0     96541.0    143014.0    100863.0    170555.0
# 2       6267.0      1305.0      6334.0      4322.0      5180.0      2930.0
# 3       2487.0      3531.0      3974.0      3200.0      2963.0      3630.0
# 4      31073.0     34239.0     36731.0     78813.0     44321.0    100110.0
# 5      23500.0     23165.0     29307.0     28206.0     25452.0     33906.0
# 6       5850.0      6183.0      5759.0     13241.0     11792.0      6368.0
# 7      12087.0     13460.0     14436.0     15232.0     11155.0     23611.0
# 8     600824.0    641972.0    743176.0    986104.0   1077737.0   1077641.0
# 9      46098.0     50816.0     74706.0     62718.0     88516.0     73779.0
# 10    121191.0    149356.0    175827.0    182666.0    241875.0    269825.0
# 11    424771.0    435536.0    483375.0    662816.0    670088.0    717355.0
# 12      8764.0      6264.0      9268.0     77904.0     77258.0     16682.0

# %%
corp.report(
    rtype='cash_flow',
    account_level=2,
    unit=1_000_000,
    first_period='2015-01-01')
# Out:
#                                 account_name account_code  account_fixed  \
# 0      Caixa Líquido Atividades Operacionais         6.01           True
# 1   Caixa Líquido Atividades de Investimento         6.02           True
# 2  Caixa Líquido Atividades de Financiamento         6.03           True
# 3   Variação Cambial s/ Caixa e Equivalentes         6.04           True
# 4  Aumento (Redução) de Caixa e Equivalentes         6.05           True
#
#    2015-06-30  2016-06-30  2017-06-30  2018-06-30  2019-06-30  2020-06-30  \
# 0     -11.175      -6.440      65.051      -2.264      51.338      69.024
# 1      19.952     149.773     -13.527     -65.700     -21.266     -29.295
# 2     -19.902    -164.749     -61.930     125.414     -27.621      18.451
# 3         NaN         NaN         NaN       3.066      -0.138       6.238
# 4     -11.125     -21.416     -10.406      60.516       2.313      64.418
#
#    2021-06-30  2021-12-31 (ltm)
# 0     151.232           252.001
# 1    -214.009          -194.268
# 2     954.857           678.425
# 3      -4.018            -0.268
# 4     888.062           735.890

# %%
accounts = [
    '3.01', '3.02', '3.03', '3.04', '3.04.01', '3.04.02', '3.04.03', '3.04.04',
    '3.04.05', '3.04.06', '3.05', '3.06', '3.07', '3.08', '3.09', '3.10',
    '3.10.01', '3.11', '1.01', '1.01.01', '1.01.02', '1.01.03', '1.01.04',
    '1.01.05', '1.01.06', '1.01.07', '1.01.08', '1.02.01', '1.02.02',
    '1.02.03', '1.02.04', '2.01', '2.01.01', '2.01.02', '2.01.03', '2.01.04',
    '2.01.05', '2.01.06', '2.02', '2.02.01', '2.02.02', '2.02.03', '2.02.04',
    '2.03', '2.03.09', '6.01', '6.01.01', '6.01.02'
]
df = corp.custom_report(
    accounts,
    unit=1_000_000,
    first_period='2015-01-01',
    accounting_method='separate')
df
# Out:
#                                          account_name account_code  \
# 0                                    Ativo Circulante         1.01
# 1                       Caixa e Equivalentes de Caixa      1.01.01
# 2                              Aplicações Financeiras      1.01.02
# 3                                    Contas a Receber      1.01.03
# 4                                            Estoques      1.01.04
# ..                                                ...          ...
# 38  Lucro/Prejuízo Líquido das Operações Descontin...      3.10.01
# 39                          Lucro/Prejuízo do Período         3.11
# 40              Caixa Líquido Atividades Operacionais         6.01
# 41                         Caixa Gerado nas Operações      6.01.01
# 42                    Variações nos Ativos e Passivos      6.01.02
#
#     account_fixed  2015-12-31  2016-12-31  2017-12-31  2018-12-31  2019-12-31  \
# 0            True     81479.0     81264.0     81883.0     96541.0    143014.0
# 1            True     16553.0      6267.0      1305.0      6334.0      4322.0
# 2            True      2982.0      2487.0      3531.0      3974.0      3200.0
# 3            True     27701.0     31073.0     34239.0     36731.0     78813.0
# 4            True     24015.0     23500.0     23165.0     29307.0     28206.0
# ..            ...         ...         ...         ...         ...         ...
# 38           True         NaN         NaN         NaN      2275.0      9865.0
# 39           True    -34836.0    -14824.0      -446.0     25779.0     40137.0
# 40           True     50040.0     37261.0     33302.0     29501.0     49200.0
# 41           True     63700.0     71036.0     68700.0     84368.0    131391.0
# 42           True    -13660.0    -33775.0    -35398.0    -54867.0    -82191.0
#
#     2020-12-31  2021-12-31
# 0     100863.0    170555.0
# 1       5180.0      2930.0
# 2       2963.0      3630.0
# 3      44321.0    100110.0
# 4      25452.0     33906.0
# ..         ...         ...
# 38         NaN         NaN
# 39      7108.0    106668.0
# 40     73236.0    123871.0
# 41    127286.0    209675.0
# 42    -54050.0    -85804.0
#
# [43 rows x 10 columns]

# %%
corp.operating_performance(accounting_method='separate')
# Out:
#                    2009-12-31  2010-12-31  2011-12-31  2012-12-31  2013-12-31  \
# return_on_assets          NaN    0.087241    0.050897    0.028849    0.031836
# return_on_capital         NaN    0.146400    0.076704    0.041635    0.047647
# return_on_equity          NaN    0.212316    0.107709    0.063227    0.071196
# gross_margin         0.433152    0.385673    0.323689    0.227581    0.211794
# operating_margin     0.201706    0.177840    0.129210    0.065706    0.074761
# net_margin           0.223516    0.223894    0.180070    0.096137    0.098599
#
#                    2014-12-31  2015-12-31  2016-12-31  2017-12-31  2018-12-31  \
# return_on_assets    -0.027633   -0.017273    0.009460    0.026105    0.048726
# return_on_capital   -0.036636   -0.022229    0.012227    0.034507    0.066219
# return_on_equity    -0.062308   -0.112793   -0.058195   -0.001782    0.097653
# gross_margin         0.227750    0.303980    0.310857    0.315203    0.356625
# operating_margin    -0.064906   -0.043898    0.029629    0.078109    0.125473
# net_margin          -0.080469   -0.138776   -0.066455   -0.001956    0.091708
#
#                    2019-12-31  2020-12-31  2021-12-31
# return_on_assets     0.066447    0.047806    0.117859
# return_on_capital    0.093542    0.064332    0.162309
# return_on_equity     0.144781    0.024051    0.345864
# gross_margin         0.366567    0.400543    0.459305
# operating_margin     0.192965    0.212521    0.310854
# net_margin           0.138807    0.027985    0.238705

# %%
corp.operating_performance()
# Out:
#                    2009-12-31  2010-12-31  2011-12-31  2012-12-31  2013-12-31  \
# return_on_assets          NaN    0.085298    0.056479    0.034618    0.033893
# return_on_capital         NaN    0.124446    0.078821    0.047732    0.047424
# return_on_equity          NaN    0.214996    0.106864    0.063088    0.069555
# gross_margin         0.405435    0.359820    0.316316    0.251999    0.229247
# operating_margin     0.160412    0.141097    0.119549    0.073830    0.074373
# net_margin           0.182374    0.169378    0.135597    0.074488    0.075460
#
#                    2014-12-31  2015-12-31  2016-12-31  2017-12-31  2018-12-31  \
# return_on_assets    -0.019210   -0.010971    0.012085    0.030971    0.049580
# return_on_capital   -0.025337   -0.014684    0.016734    0.043979    0.074909
# return_on_equity    -0.062759   -0.113191   -0.050576    0.001492    0.099025
# gross_margin         0.238501    0.306481    0.318406    0.322864    0.382547
# operating_margin    -0.042888   -0.027062    0.038494    0.087877    0.132881
# net_margin          -0.065006   -0.109350   -0.046162    0.001329    0.086052
#
#                    2019-12-31  2020-12-31  2021-12-31
# return_on_assets     0.062666    0.035367    0.140921
# return_on_capital    0.097621    0.053079    0.217617
# return_on_equity     0.144493    0.020880    0.344734
# gross_margin         0.403993    0.455627    0.485205
# operating_margin     0.178407    0.120373    0.307396
# net_margin           0.135552    0.022957    0.236960

# %%
corp.s
# Out:
# Downloading CVM raw files...
#
# Processing CVM raw dataset...
# itr_cia_aberta_2022.zip processed
# dfp_cia_aberta_2021.zip processed
# dfp_cia_aberta_2016.zip processed
# dfp_cia_aberta_2013.zip processed
# dfp_cia_aberta_2018.zip processed
# dfp_cia_aberta_2010.zip processed
# dfp_cia_aberta_2012.zip processed
# dfp_cia_aberta_2014.zip processed
# dfp_cia_aberta_2011.zip
# processeddfp_cia_aberta_2015.zip processed
# dfp_cia_aberta_2017.zip processed
# dfp_cia_aberta_2019.zip processed
# dfp_cia_aberta_2020.zip processed
# itr_cia_aberta_2020.zip processed
# itr_cia_aberta_2021.zip processed
#
# Concatenating dataframes ...
# Columns data type changed to category
#
# Processed dataset saved

# %%
bf.update_dataset()
# Out:
# Downloading CVM raw files...
# dfp_cia_aberta_2012.zip new/outdated -> download file
# dfp_cia_aberta_2013.zip new/outdated -> download file
# dfp_cia_aberta_2010.zip new/outdated -> download file
# dfp_cia_aberta_2015.zip new/outdated -> download file
# dfp_cia_aberta_2011.zip new/outdated -> download file
# dfp_cia_aberta_2021.zip new/outdated -> download file
# dfp_cia_aberta_2020.zip new/outdated -> download file
# itr_cia_aberta_2021.zip new/outdated -> download file
# dfp_cia_aberta_2017.zip new/outdated -> download file
# itr_cia_aberta_2020.zip new/outdated -> download file
# dfp_cia_aberta_2019.zip new/outdated -> download file
# dfp_cia_aberta_2018.zip new/outdated -> download file
# dfp_cia_aberta_2016.zip new/outdated -> download file
# itr_cia_aberta_2022.zip new/outdated -> download file
# dfp_cia_aberta_2014.zip new/outdated -> download file
# http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/dfp_cia_aberta_2010.zip
# http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/dfp_cia_aberta_2011.zip
# http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/dfp_cia_aberta_2012.zip
# http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/dfp_cia_aberta_2013.zip
# http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/dfp_cia_aberta_2014.zip
# http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/dfp_cia_aberta_2015.zip
# http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/dfp_cia_aberta_2016.zip
# http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/dfp_cia_aberta_2017.zip
# http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/dfp_cia_aberta_2018.zip
# http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/dfp_cia_aberta_2019.zip
# http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/dfp_cia_aberta_2020.zip
# http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/ITR/DADOS/itr_cia_aberta_2020.zip
# http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/dfp_cia_aberta_2021.zip
# http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/ITR/DADOS/itr_cia_aberta_2021.zip
# http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/ITR/DADOS/itr_cia_aberta_2022.zip
#
# Processing CVM raw dataset...
# itr_cia_aberta_2022.zip processed
# dfp_cia_aberta_2021.zip processed
# dfp_cia_aberta_2010.zip processed
# dfp_cia_aberta_2016.zip processed
# dfp_cia_aberta_2014.zip dfp_cia_aberta_2013.zipprocessed processed
#
# dfp_cia_aberta_2015.zip processed
# dfp_cia_aberta_2011.zip processed
# dfp_cia_aberta_2012.zip processed
# dfp_cia_aberta_2017.zip processed
# dfp_cia_aberta_2018.zip processed
# dfp_cia_aberta_2019.zip processed
# dfp_cia_aberta_2020.zip processed
# itr_cia_aberta_2020.zip processed
# itr_cia_aberta_2021.zip processed
#
# Concatenating dataframes ...
# Columns data type changed to category
#
# Processed dataset saved
